# %%
from nmr_processing.leonmr import get_2D_data

# %%
filepath = '/Users/tylerpennebaker/Documents/UCSB_Grad/Clement Group/Project/EXSY Study/800.ES.TP-2024.02.19_LZC+Pristine_LPSC/30'

# %%
x,y,ints = get_2D_data(filepath, homonuclear=True)

# %%
x,y,ints = get_2D_data(filepath, homonuclear=True, f1l=3, f1r=-3, f2l=3, f2r=-3)

# %%
l = []
for iy in range(len(y)):
    for ix in range(len(x)):
        l.append([x[ix], y[iy], ints[iy,ix]])

# %%
import pandas as pd

# %%
pd.DataFrame(l,columns=['F2 (ppm)', 'F1 (ppm)', 'Intensity'])

# %%
pd.DataFrame(l,columns=['F2 (ppm)', 'F1 (ppm)', 'Intensity']).to_csv?

# %%
pd.DataFrame(l,columns=['F2 (ppm)', 'F1 (ppm)', 'Intensity']).to_csv('LZC+Pristine_LPSC_2DEXSYspectrum.csv')

# %%
pd.DataFrame(l,columns=['F2 (ppm)', 'F1 (ppm)', 'Intensity']).to_csv('LZC+Pristine_LPSC_2DEXSYspectrum.csv', index=False)
